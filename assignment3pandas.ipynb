# %%
#assignment3 pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1=pd.read_csv(r"https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv")
df1
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
# ...

# %%
#1. Get the Metadata from the above files.

# %%
ab=df1.info()
print(ab)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
# None

# %%
#2. Get the row names from the above files.

# %%
for row in df1.index:
    print(row,end="")
# Out:
# ...
# ...

# %%
#3. Change the column name from any of the above file and store the changes made permanently.

# %%
df1.rename(columns={'PUBLISH STATES':'STATES'},inplace=True)
df1.head()
# Out:
#                            Indicator     STATES  Year             WHO region  \
# 0   Life expectancy at birth (years)  Published  1990                 Europe
# 1   Life expectancy at birth (years)  Published  2000                 Europe
# 2  Life expectancy at age 60 (years)  Published  2012                 Europe
# 3  Life expectancy at age 60 (years)  Published  2000                 Europe
# 4   Life expectancy at birth (years)  Published  2012  Eastern Mediterranean
#
#   World Bank income group               Country         Sex  Display Value  \
# 0             High-income               Andorra  Both sexes             77
# 1             High-income               Andorra  Both sexes             80
# 2             High-income               Andorra      Female             28
# 3             High-income               Andorra  Both sexes             23
# 4             High-income  United Arab Emirates      Female             78
#
#    Numeric  Low  High  Comments
# ...

# %%
#4. Change the names of multiple columns.

# %%
df2=df1.rename(columns={'WHO region':'regions','Year':'YEAR'},inplace=False)
df2.head()
# Out:
#                            Indicator     STATES  YEAR                regions  \
# 0   Life expectancy at birth (years)  Published  1990                 Europe
# 1   Life expectancy at birth (years)  Published  2000                 Europe
# 2  Life expectancy at age 60 (years)  Published  2012                 Europe
# 3  Life expectancy at age 60 (years)  Published  2000                 Europe
# 4   Life expectancy at birth (years)  Published  2012  Eastern Mediterranean
#
#   World Bank income group               Country         Sex  Display Value  \
# 0             High-income               Andorra  Both sexes             77
# 1             High-income               Andorra  Both sexes             80
# 2             High-income               Andorra      Female             28
# 3             High-income               Andorra  Both sexes             23
# 4             High-income  United Arab Emirates      Female             78
#
#    Numeric  Low  High  Comments
# ...

# %%
#5. Arrange values of a particular column in ascending order.

# %%
df4=df1.sort_values('Year',ascending="True")
df4.head()
# Out:
#                               Indicator STATES PUBLISH  Year WHO region  \
# 0      Life expectancy at birth (years)      Published  1990     Europe
# 1270   Life expectancy at birth (years)      Published  1990     Europe
# 3193   Life expectancy at birth (years)      Published  1990     Europe
# 3194   Life expectancy at birth (years)      Published  1990     Europe
# 3197  Life expectancy at age 60 (years)      Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %%
#6. Arrange multiple column values in ascending order.

# %%
df5=df1.sort_values(['WHO region','World Bank income group'],ascending="True")
df5.head()
# Out:
#                              Indicator STATES PUBLISH  Year WHO region  \
# 63    Life expectancy at birth (years)      Published  2000     Africa
# 64   Life expectancy at age 60 (years)      Published  1990     Africa
# 65   Life expectancy at age 60 (years)      Published  2012     Africa
# 479  Life expectancy at age 60 (years)      Published  1990     Africa
# 882   Life expectancy at birth (years)      Published  2012     Africa
#
#     World Bank income group            Country         Sex  Display Value  \
# 63              High-income  Equatorial Guinea      Female             52
# 64              High-income  Equatorial Guinea      Female             15
# 65              High-income  Equatorial Guinea      Female             17
# 479             High-income  Equatorial Guinea  Both sexes             15
# 882             High-income  Equatorial Guinea  Both sexes             55
#
#      Numeric  Low  High  Comments
# 63      52.0  NaN   NaN       NaN
# ...

# %%
#7. Make country as the first column of the dataframe.
df6=df1.set_index('Country')
df6.head()
# Out:
#                                               Indicator STATES PUBLISH  Year  \
# Country
# Andorra                Life expectancy at birth (years)      Published  1990
# Andorra                Life expectancy at birth (years)      Published  2000
# Andorra               Life expectancy at age 60 (years)      Published  2012
# Andorra               Life expectancy at age 60 (years)      Published  2000
# United Arab Emirates   Life expectancy at birth (years)      Published  2012
#
#                                  WHO region World Bank income group  \
# Country
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# United Arab Emirates  Eastern Mediterranean             High-income
#
# ...

# %%
#8. Get the column array using a variable\
c=list(df1.columns.values)
print(c)
# Out:
# ['Indicator', 'STATES PUBLISH', 'Year', 'WHO region', 'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']

# %%
#9. Get the subset rows 11, 24, 37
df1.iloc[[11,24,37]]
# Out:
#                             Indicator STATES PUBLISH  Year       WHO region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank income group            Country     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
#10. Get the subset rows excluding 5, 12, 23, and 56
df7=df1
df7.drop([5,12,23,56],axis=0).head(65)
# Out:
#                             Indicator STATES PUBLISH  Year  \
# 0    Life expectancy at birth (years)      Published  1990
# 1    Life expectancy at birth (years)      Published  2000
# 2   Life expectancy at age 60 (years)      Published  2012
# 3   Life expectancy at age 60 (years)      Published  2000
# 4    Life expectancy at birth (years)      Published  2012
# ..                                ...            ...   ...
# 64  Life expectancy at age 60 (years)      Published  1990
# 65  Life expectancy at age 60 (years)      Published  2012
# 66   Life expectancy at birth (years)      Published  2012
# 67   Life expectancy at birth (years)      Published  2012
# 68   Life expectancy at birth (years)      Published  2012
#
#                WHO region World Bank income group               Country  \
# 0                  Europe             High-income               Andorra
# 1                  Europe             High-income               Andorra
# ...

# %%
#11. find rows with NaN values
df1[df1.isna().any(axis=1)]
# Out:
#                                             Indicator STATES PUBLISH  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
# ...

# %%
#12. show rows from dataset 1 country = india with high income
y=df1[(df1['World Bank income group']=='High_income')]
y
# Out:
# Empty DataFrame
# Columns: [Indicator, STATES PUBLISH, Year, WHO region, World Bank income group, Country, Sex, Display Value, Numeric, Low, High, Comments]
# Index: []
